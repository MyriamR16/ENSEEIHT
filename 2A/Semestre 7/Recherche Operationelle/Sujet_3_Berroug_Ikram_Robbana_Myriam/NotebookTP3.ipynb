# %% [markdown]
# # TP 3 : Programmation Dynamique

# %% [markdown]
# ### Réponse à la Question 1
#
# La programmation dynamique est une méthode algorithmique qui résout des problèmes complexes en les décomposant en sous-problèmes plus simples et en réutilisant les solutions de ces sous-problèmes pour construire progressivement la solution du problème global. Chaque sous-problème est résolu de manière optimale et stocké pour éviter de le recalculer plusieurs fois. La solution finale est souvent obtenue en parcourant les sous-problèmes résolus à rebours. Ce procédé repose sur une relation de récurrence, qui décrit comment la solution d'un sous-problème peut être construite à partir de celles des sous-problèmes plus petits.

# %% [markdown]
# ### Réponse à la Question 2

# %%
function problemeSacADos(couts, poids, objets, Q)
    n = length(poids)
    C = zeros(Int64, n, Q+1)
    
    for j in 0:Q
        if j >= poids[1]
            C[1,j+1] = couts[1]
        end
        for i in 2:n
            if j>= poids[i]
                C[i,j+1] = max(C[i-1,j+1],C[i-1,j-poids[i]+1] + couts[i])
            else
                C[i,j+1] = C[i-1,j+1]
            end
        end
    end

    CoutOptimal = C[n,Q+1]
    ListeObjetsAjoutes = []
    var = C[n,Q+1]
    i = n
    j = Q+1

    while var !=0 && i>0
        if i == 1
            if var > 0
                push!(ListeObjetsAjoutes, objets[i])
            end
            break
        else 
            if var > C[i-1,j]
                push!(ListeObjetsAjoutes,objets[i])
                j -= poids[i]
                i -= 1
                var = C[i,j]
            else
                i-=1
            end
        end
    end
    return C, CoutOptimal , ListeObjetsAjoutes
end
# Out:
# problemeSacADos (generic function with 1 method)

# %%
objets = [1,2,3,4]
couts = [42,40,12,25]
poids = [7,4,3,5]
Q = 10 
C, CoutOptimal, ListeObjetsAjoutes= problemeSacADos(couts,poids,objets,Q)
C
# Out:
# 4×11 Matrix{Int64}:
#  0  0  0   0   0   0   0  42  42  42  42
#  0  0  0   0  40  40  40  42  42  42  42
#  0  0  0  12  40  40  40  52  52  52  54
#  0  0  0  12  40  40  40  52  52  65  65

# %%
CoutOptimal
# Out:
# 65

# %%
ListeObjetsAjoutes
# Out:
# 2-element Vector{Any}:
#  4
#  2

# %% [markdown]
# ### Réponse à la Question 3
#
# Le résultat obtenu est cohérent avec l'instance résolue.
#
# En effet, dans le problème du sac à dos, l'objectif est de maximiser la valeur des objets tout en respectant la capacité du sac, ici \( Q = 10 \). La matrice \( C \) obtenue, montre que la valeur maximale obtenue avec un sac de capacité 10 est **65**, ce qui est atteint en choisissant les objets 4 et 2, comme indiqué par la liste des objets ajoutés. Ces objets ont respectivement un coût de 25 et 40, et leur poids total est \( 5 + 4 = 9 \), ce qui respecte bien la capacité du sac de 10.
#
# Montrons maintenant que ce résultat est la solution optimale, en réalisant toutes les combinaisons possibles :
#
# - Objets 1 : Le poids total est de \(7\), ce qui respecte la capacité du sac. Ainsi, le coût total est de \(  **42** \)
#
# - Objets 2 : Le poids total est de \(4\), ce qui respecte la capacité du sac. Ainsi, le coût total est de \(  **40** \)
#
# - Objets 3 : Le poids total est de \(3\), ce qui respecte la capacité du sac. Ainsi, le coût total est de \(  **12** \)
#
# - Objets 4 : Le poids total est de \(5\), ce qui respecte la capacité du sac. Ainsi, le coût total est de \(  **25** \)
#
# - Objets 1 et 2 : Le poids total est de  \( 7 + 4 = 11 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
# - Objets 1 et 3 : Le poids total est de \( 7 + 3 = 10 \), ce qui respecte la capacité du sac. Ainsi, le coût total est de \( 42 + 12 = **54** \)
#
# - Objets 1 et 4 : Le poids total est de  \( 7 + 5 = 12 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
# - Objets 2 et 3 : Le poids total est de \( 4 + 3 = 7 \), ce qui respecte la capacité du sac. Ainsi, le coût total est de \( 40 + 12 = **52** \)
#
# - Objets 2 et 4 : Le poids total est de  \( 4 + 5 = 9 \), ce qui respecte la capacité du sac. Ainsi, le coût total est de \( 40 + 25 = **65** \)
#
# - Objets 3 et 4  : Le poids total est de \( 3 + 5 = 8 \), ce qui respecte la capacité du sac. Ainsi, le coût total est de \( 12 + 25 = **37** \)
#
# - Objets 1, 2, et 3 : Le poids total est de \( 7 + 4 + 3 = 14 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
# - Objets 1, 2, et 4 : Le poids total est de \( 7 + 4 + 5 = 16 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
# - Objets 1, 3, et 4 : Le poids total est de \( 7 + 3 + 5 = 15 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas
#
# - Objets 2, 3, et 4 : Le poids total est de \( 4 + 3 + 5 = 12 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
# - Objets 1, 2, 3, et 4 : Le poids total est de \( 7 + 4 + 3 + 5 = 19 \), ce qui dépasse la capacité du sac, donc on ne considère pas ce cas.
#
#
# Cela confirme que la solution obtenue précedemment : avec **les objets 2 et 4**, qui ont un poids total de **9** et un coût total de **65**, est bien la solution optimale !

# %% [markdown]
# ### Réponse à la Question 4
#
# L'algorithme que nous avons implanté résout le problème du sac à dos en utilisant une méthode de programmation dynamique. L'idée principale est de construire une matrice où chaque cellule représente la valeur maximale que l'on peut obtenir en sélectionnant un certain nombre d'objets avec une contrainte de poids donnée.
#
# On commence par initialiser une matrice C de dimensions (n,Q+1), où n est le nombre d'objets et Q est la capacité maximale du sac à dos. Ensuite, l'algorithme remplit cette matrice en comparant, pour chaque objet et chaque poids possible, deux choix : soit on inclut l'objet, soit on ne l'inclut pas. À chaque étape, on conserve la valeur maximale obtenue.
#
# Une fois la matrice remplie, l'algorithme procède à la remontée pour déterminer les objets sélectionnés dans la solution optimale. En partant de la dernière cellule C(n, Q), l'algorithme compare la valeur actuelle à celle de la cellule juste à côté C(i-1, j) avec au départ i=n et j=Q. Si la valeur est différente, cela signifie que l'objet i a été inclus, et on ajoute cet objet à la liste des objets sélectionnés. Ensuite, la capacité restante j est réduite de poids(i), et on passe à l'objet précédent. Si la valeur est identique à celle de la cellule à côté, l'objet i n'a pas été sélectionné, et on passe simplement à l'objet précédent sans changer la capacité du sac. Ce processus se répète jusqu'à ce qu'on trouve tous les objets qui ont permis d'obtenir le coût total optimal.

# %% [markdown]
# ### Réponse à la Question 5

# %% [markdown]
# ### Récupération des données

# %%
function readKnaptxtInstance(filename)
    price=Int64[]
    weight=Int64[]
    KnapCap=Int64[]
    open(filename) do f
        for i in 1:3
            tok = split(readline(f))
            if(tok[1] == "ListPrices=")
                for i in 2:(length(tok)-1)
                    push!(price,parse(Int64, tok[i]))
                end
            elseif(tok[1] == "ListWeights=")
                for i in 2:(length(tok)-1)
                    push!(weight,parse(Int64, tok[i]))
                end
            elseif(tok[1] == "Capacity=")
                push!(KnapCap, parse(Int64, tok[2]))
            else
                println("Unknown read :", tok)
            end
        end
    end
    capacity=KnapCap[1]
    return price, weight, capacity
end
# Out:
# readKnaptxtInstance (generic function with 1 method)

# %%
fichiers = readdir("InstancesKnapSack/Strongly_Correlated") 

for fichier in fichiers
    price, weight, capacity = readKnaptxtInstance("InstancesKnapSack/Strongly_Correlated/$(fichier)")
    n = length(price)
    _ , CoutOptimal, ListeObjetsAjoutes = problemeSacADos(price, weight, 1:n, capacity)
    
    println("Fichier: ", fichier)
    println("Valeur totale: ", CoutOptimal)
    println("Objets sélectionnés: ", ListeObjetsAjoutes)
    println("-------------------------------")
end
# Out:
# Fichier: KnapSack_1000_10000_-147980.opb.txt
# Valeur totale: 147980
# Objets sélectionnés: Any[1000, 992, 970, 920, 888, 882, 877, 864, 854, 846, 840, 837, 836, 812, 805, 792, 767, 764, 750, 748, 742, 741, 736, 735, 731, 730, 729, 722, 718, 711, 706, 697, 695, 677, 675, 674, 672, 657, 652, 650, 636, 635, 633, 618, 607, 602, 599, 587, 584, 576, 548, 525, 519, 511, 500, 490, 488, 486, 477, 472, 470, 463, 436, 430, 395, 394, 393, 391, 379, 376, 364, 358, 348, 347, 336, 330, 328, 325, 320, 286, 248, 229, 218, 170, 163, 129, 116, 111, 98, 76, 65, 51, 50, 47, 32, 21, 9, 8, 1]
# -------------------------------
# Fichier: KnapSack_1000_1000_-14390.opb.txt
# Valeur totale: 14390
# ...

# %%
fichiers = readdir("InstancesKnapSack/Weakly_Correlated") 

for fichier in fichiers
    price, weight, capacity = readKnaptxtInstance("InstancesKnapSack/Weakly_Correlated/$(fichier)")
    n = length(price)
    _ , CoutOptimal, ListeObjetsAjoutes = problemeSacADos(price, weight, 1:n, capacity)
    
    println("Fichier: ", fichier)
    println("Valeur totale: ", CoutOptimal)
    println("Objets sélectionnés: ", ListeObjetsAjoutes)
    println("-------------------------------")
end
# Out:
# Fichier: KnapSack_1000_10000_-90707.opb.txt
# Valeur totale: 90707
# Objets sélectionnés: Any[989, 963, 883, 857, 816, 785, 781, 774, 772, 761, 760, 735, 696, 691, 677, 657, 633, 628, 624, 619, 615, 609, 604, 587, 580, 566, 563, 557, 555, 549, 521, 506, 503, 501, 462, 439, 419, 411, 384, 356, 349, 348, 333, 304, 294, 256, 242, 227, 198, 197, 196, 174, 163, 114, 96, 65, 26, 24, 5, 1]
# -------------------------------
# Fichier: KnapSack_1000_1000_-9052.opb.txt
# Valeur totale: 9052
# Objets sélectionnés: Any[990, 974, 968, 946, 846, 831, 828, 808, 776, 771, 744, 737, 733, 727, 709, 670, 659, 658, 644, 611, 604, 600, 574, 569, 551, 540, 480, 474, 470, 464, 453, 447, 427, 422, 398, 380, 318, 293, 290, 270, 263, 250, 246, 237, 212, 199, 160, 157, 148, 138, 110, 85, 71, 57, 54, 45, 38, 33, 24]
# -------------------------------
# Fichier: KnapSack_100_10000_-15785.opb.txt
# Valeur totale: 15785
# Objets sélectionnés: Any[99, 96, 65, 33, 27, 26, 24, 5, 1]
# -------------------------------
# ...

# %%
fichiers = readdir("InstancesKnapSack/Similar_Weights") 

for fichier in fichiers
    price, weight, capacity = readKnaptxtInstance("InstancesKnapSack/Similar_Weights/$(fichier)")
    n = length(price)
    _ , CoutOptimal, ListeObjetsAjoutes = problemeSacADos(price, weight, 1:n, capacity)
    
    println("Fichier: ", fichier)
    println("Valeur totale: ", CoutOptimal)
    println("Objets sélectionnés: ", ListeObjetsAjoutes)
    println("-------------------------------")
end
# Out:
# Fichier: KnapSack_1000_1000_-8943.opb.txt
# Valeur totale: 8943
# Objets sélectionnés: Any[889, 858, 814, 782, 559, 279, 273, 77, 29]
# -------------------------------
# Fichier: KnapSack_100_1000_-995.opb.txt
# Valeur totale: 995
# Objets sélectionnés: Any[29]
# -------------------------------
# OutOfMemoryError()
#
# Stacktrace:
#  [1] Array
#    @ ./boot.jl:461 [inlined]
#  [2] Array
#    @ ./boot.jl:469 [inlined]
#  [3] zeros
#    @ ./array.jl:588 [inlined]
#  [4] zeros
#    @ ./array.jl:584 [inlined]
#  [5] problemeSacADos(couts::Vector{Int64}, poids::Vector{Int64}, objets::UnitRange{Int64}, Q::Int64)
#    @ Main ./In[1]:3
#  [6] top-level scope
#    @ ./In[8]:6

# %% [markdown]
# On peut voir que certains fichiers de test sont beacoup trop volumineux pour être traités sur ce notebook d'où l'erreur "OutOfMemoryError".

# %%
fichiers = readdir("InstancesKnapSack/Uncorrelated/") 

for fichier in fichiers
    price, weight, capacity = readKnaptxtInstance("InstancesKnapSack/Uncorrelated/$(fichier)")
    n = length(price)
    _ , CoutOptimal, ListeObjetsAjoutes = problemeSacADos(price, weight, 1:n, capacity)
    
    println("Fichier: ", fichier)
    println("Valeur totale: ", CoutOptimal)
    println("Objets sélectionnés: ", ListeObjetsAjoutes)
    println("-------------------------------")
end
# Out:
# Fichier: KnapSack_1000_10000_-524753.opb.txt
# Valeur totale: 524753
# Objets sélectionnés: Any[993, 989, 978, 963, 945, 943, 918, 904, 900, 850, 843, 841, 808, 787, 785, 774, 772, 761, 743, 733, 732, 729, 727, 701, 696, 684, 653, 639, 638, 633, 619, 617, 615, 604, 585, 580, 575, 566, 563, 559, 557, 542, 534, 520, 508, 506, 501, 439, 435, 419, 413, 403, 384, 377, 366, 349, 348, 338, 329, 304, 300, 294, 263, 260, 239, 232, 198, 196, 190, 163, 157, 115, 114, 82, 79, 33, 26, 24, 11, 5, 1]
# -------------------------------
# Fichier: KnapSack_1000_1000_-54503.opb.txt
# Valeur totale: 54503
# ...

# %% [markdown]
# ### Réponse à la Question 6

# %% [markdown]
# On commence par intégrer ci-dessous l'algorithme de Branch and Bound.

# %%
using JuMP, Clp #to comment for the lab class


function testSondability_LP(model2, x, BestProfit, Bestsol)
    TA, TO, TR = false, false, false
    if(termination_status(model2) == MOI.INFEASIBLE)#Test de faisabilite
        TA=true
    elseif(objective_value(model2) <= BestProfit) #Test d'optimalite
        TO=true
    elseif( prod(abs.([round.(v, digits=0) for v in value.(x)]-value.(x)) .<= fill(10^-5, size(x)))
        ) #Test de resolution
        TR=true
        #if (value(benef) >= BestProfit)
        if (objective_value(model2) >= BestProfit)
            Bestsol = value.(x)
            #BestProfit=value(benef)
            BestProfit=objective_value(model2)
        end
    else
    end
    TA, TO, TR, Bestsol, BestProfit
end

function separateNodeThenchooseNext_lexicographic_depthfirst!(listobjs, listvals, n)
    # this node is non-sondable. Apply the branching criterion to separate it into two subnodes
    # and choose the child-node at the left

    # lexicographic branching criterion: branch on the 1st object not yet fixed
    i, obj = 1, 0
    while((i <= n) && (obj==0))
        if(!(i in listobjs))
            obj=i
        end
        i+=1
    end


    # depthfirst exploration strategy: the node selected will be the most left of the child-nodes just created
    push!(listobjs,obj) #save the identity of the object selected for branching
    push!(listvals,1.0) #save the node selected, identified by the value assigned to the variable/object chosen
end


function exploreNextNode_depthfirst!(listobjs, listvals, listnodes)
    #this node is sondable, go back to parent node then right child if possible

    stop=false
    #check if we are not at the root node
    if (length(listobjs)>= 1)
        #go back to parent node
        obj=pop!(listobjs)
        theval=pop!(listvals)
        tmp=pop!(listnodes)

        #go to right child if possible, otherwise go back to parent
        while( (theval==0.0) && (length(listobjs)>= 1))
            obj=pop!(listobjs)
            theval=pop!(listvals)
            tmp=pop!(listnodes)
        end
        if theval==1.0
            push!(listobjs,obj)
            push!(listvals,0.0)
        else
            stop=true
        end
    else
        #the root node was sondable
        stop=true
    end
    return stop
end


function updateModele_LP!(model2, x, listobjs, listvals)
    for i in 1:length(listobjs)
        set_lower_bound(x[listobjs[i]],listvals[i])
        set_upper_bound(x[listobjs[i]],listvals[i])
    end
end

function reset_LP!(model2, x, listobjs)
    for i in 1:length(listobjs)
        set_lower_bound(x[listobjs[i]],0.0)
        set_upper_bound(x[listobjs[i]],1.0)
    end
end

function resetAll_LP!(model2, x)
    for i in 1:length(x)
        set_lower_bound(x[i],0.0)
        set_upper_bound(x[i],1.0)
    end
end

function createModel_LP(price, weight, capacity)
# ROOT NODE

    n=length(price)

    model2 = Model(Clp.Optimizer) # set optimizer
    set_optimizer_attribute(model2, "LogLevel", 0) #don't display anything during solve
    set_optimizer_attribute(model2, "Algorithm", 4) #LP solver chosen is simplex

    # define x variables as CONTINUOUS (recall that it is not possible to define binary variables in Clp)
    @variable(model2, 0 <= x[i in 1:n] <= 1)

    # define objective function
    @objective(model2, Max, sum(price[i]*x[i] for i in 1:n))

    # define the capacity constraint
    @constraint(model2, sum(weight[i]*x[i] for i in 1:n) <=  capacity)

    return model2, x
end

function solveKnapInstance(filename)

    price, weight, capacity = readKnaptxtInstance(filename)

    model2, x = createModel_LP(price, weight, capacity)
    
    #create the structure to memorize the search tree for visualization at the end
    trParentnodes=Int64[] #will store orig node of arc in search tree
    trChildnodes=Int64[] #will store destination node of arc in search tree
    trNamenodes=[] #will store names of nodes in search tree
    
    #intermediate structure to navigate in the search tree
    listobjs=Int64[]
    listvals=Float64[]
    listnodes=Int64[]

    BestProfit::Float64=-1.0
    Bestsol=Float64[]

    current_node_number::Int64=0
    stop = false

    while(!stop)
        
        push!(listnodes, current_node_number)
        
        #create LP of current node
        updateModele_LP!(model2, x, listobjs, listvals)
        

        status = optimize!(model2)

        TA, TO, TR, Bestsol, BestProfit = testSondability_LP(model2, x, BestProfit, Bestsol)

        is_node_sondable = TA || TO || TR

        #Reset_LP!(model2, x, listobjs)

        if(!is_node_sondable)
            separateNodeThenchooseNext_lexicographic_depthfirst!(listobjs, listvals, length(price))
        else
            stop = exploreNextNode_depthfirst!(listobjs, listvals, listnodes)
        end
        
        resetAll_LP!(model2, x)

        current_node_number = current_node_number + 1
    end
    return BestProfit, Bestsol, trParentnodes, trChildnodes, trNamenodes

end
# Out:
# solveKnapInstance (generic function with 1 method)

# %%
fichiers = ["InstancesKnapSack/Weakly_Correlated/KnapSack_100_1000_-1514.opb.txt",
    "InstancesKnapSack/Strongly_Correlated/KnapSack_100_1000_-2397.opb.txt",
    "InstancesKnapSack/Uncorrelated/KnapSack_100_1000_-9147.opb.txt", 
    "InstancesKnapSack/Similar_Weights/KnapSack_100_1000_-995.opb.txt"
]

for fichier in fichiers
    start_time1 = time()
    price, weight, capacity = readKnaptxtInstance(fichier)
    n = length(price)
        _ , _, _ = problemeSacADos(price, weight, 1:n, capacity)
    end_time1 = time()
    temps1 = end_time1 - start_time1
    
    start_time2 = time()
    _, _, _, _, _ = solveKnapInstance(fichier)
    end_time2 = time() 
    temps2= end_time2- start_time2
    
    println("La durée d'exécution du test $fichier :")
    println(" - programmation dynamique : $temps1 secondes.")
    println(" - branch and bound : $temps2 secondes.")

end
# Out:
# UndefVarError: readKnaptxtInstance not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[2]:9

# %% [markdown]
# #### Analyse des résultats :
#
# Les différences de temps d'exécution observées entre la programmation dynamique et le branch and bound peuvent être expliquées par la nature des algorithmes. La programmation dynamique a une complexité de $O(nQ)$, où $n$ est le nombre d'éléments et $Q$ la capacité du sac à dos. Cette méthode est particulièrement efficace pour les problèmes de taille modérée, comme ceux avec des corrélations faibles, car elle résout les sous-problèmes de manière optimale en réutilisant les résultats précédents. Cela explique pourquoi elle reste très rapide, avec des temps d'exécution de l'ordre de la milliseconde, même pour des problèmes complexes.
#
# En revanche, le branch and bound a une complexité exponentielle dans le pire des cas, car il explore l'arbre de décision de manière exhaustive. Dans le cas du sac à dos, l'espace de recherche peut atteindre $2^n$ solutions possibles, où $n$ est le nombre d'éléments, ce qui conduit à une complexité de $O(2^n)$. La durée d'exécution peut donc rapidement augmenter, notamment sur des problèmes fortement corrélés, où l'arbre de recherche est vaste. C'est ainsi que l'algorithme peut atteindre des temps d'exécution bien plus longs, comme les 12 secondes observées pour certaines instances.
